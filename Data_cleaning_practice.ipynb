# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv("data_cleaning_challenge.csv")
df
# Out:
#                  Row Type       Iter Number             Power1  Speed1  \
# 0      first name: Person  last name: Human  date: end of time     NaN
# 1                     NaN               NaN                NaN     NaN
# 2                Row Type       Iter Number             Power1  Speed1
# 3                    Iter                 1                360     108
# 4                    Iter                 2                684     508
# ...                   ...               ...                ...     ...
# 76372                Iter                 6                879      73
# 76373             Average               979                641     531
# 76374             Maximum               783                172     941
# 76375            Std.Dev.               221                112     717
# 76376               Total               429                  -       -
#
#        Speed2  Electricity  Effort  Weight  Torque  Unnamed: 9 Unnamed: 10
# ...

# %% [markdown]
# ### Required file output
# <img src='./images/final_goal.png'>

# %%
# Drop the extra columns
df = df.drop(columns=["Unnamed: 9", "Unnamed: 10"])
df
# Out:
#                  Row Type       Iter Number             Power1  Speed1  \
# 0      first name: Person  last name: Human  date: end of time     NaN
# 1                     NaN               NaN                NaN     NaN
# 2                Row Type       Iter Number             Power1  Speed1
# 3                    Iter                 1                360     108
# 4                    Iter                 2                684     508
# ...                   ...               ...                ...     ...
# 76372                Iter                 6                879      73
# 76373             Average               979                641     531
# 76374             Maximum               783                172     941
# 76375            Std.Dev.               221                112     717
# 76376               Total               429                  -       -
#
#        Speed2  Electricity  Effort  Weight  Torque
# 0         NaN          NaN     NaN     NaN     NaN
# ...

# %%
# Drop nan in column 'Row Type'
df = df[df["Row Type"].notna()]
df.head()
# Out:
#              Row Type       Iter Number             Power1  Speed1  Speed2  \
# 0  first name: Person  last name: Human  date: end of time     NaN     NaN
# 2            Row Type       Iter Number             Power1  Speed1  Speed2
# 3                Iter                 1                360     108     863
# 4                Iter                 2                684     508     613
# 5                Iter                 3                365     126     825
#
#    Electricity  Effort  Weight  Torque
# 0          NaN     NaN     NaN     NaN
# 2  Electricity  Effort  Weight  Torque
# 3          599     680     442     982
# 4          241     249     758     639
# 5          407     855     164      86

# %%
# Count whole users amount -> calculate how many user based on 'Row Type'
count_values = []
amount = 0
for ele in df["Row Type"]:
    if 'first name' in ele:
       amount += 1
    count_values.append(amount)

# %%
# Add new column on df
df['Iteration'] = count_values
df.head(11)
# Out:
# <ipython-input-19-58c67d6d5988>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Iteration'] = count_values
#               Row Type       Iter Number             Power1  Speed1  Speed2  \
# 0   first name: Person  last name: Human  date: end of time     NaN     NaN
# 2             Row Type       Iter Number             Power1  Speed1  Speed2
# 3                 Iter                 1                360     108     863
# 4                 Iter                 2                684     508     613
# 5                 Iter                 3                365     126     825
# 6                 Iter                 4                764     594     304
# 7                 Iter                 5                487      97     593
# ...

# %% [markdown]
# ## Split into two dataset

# %% [markdown]
# ### Dataframe1 with name

# %%
df_name = df.loc[df["Row Type"].str.contains("first name")]
# Out:
#                  Row Type       Iter Number             Power1 Speed1 Speed2  \
# 0      first name: Person  last name: Human  date: end of time    NaN    NaN
# 14     first name: Person  last name: Human  date: end of time    NaN    NaN
# 28     first name: Person  last name: Human  date: end of time    NaN    NaN
# 42     first name: Person  last name: Human  date: end of time    NaN    NaN
# 56     first name: Person  last name: Human  date: end of time    NaN    NaN
# ...                   ...               ...                ...    ...    ...
# 76309  first name: Person  last name: Human  date: end of time    NaN    NaN
# 76322  first name: Person  last name: Human  date: end of time    NaN    NaN
# 76336  first name: Person  last name: Human  date: end of time    NaN    NaN
# 76350  first name: Person  last name: Human  date: end of time    NaN    NaN
# 76364  first name: Person  last name: Human  date: end of time    NaN    NaN
#
# ...

# %%
cols = list(df_name.columns)
df_name = df_name[cols[:3] + [cols[-1]]]
df_name
# Out:
#                  Row Type       Iter Number             Power1  Iteration
# 0      first name: Person  last name: Human  date: end of time          1
# 14     first name: Person  last name: Human  date: end of time          2
# 28     first name: Person  last name: Human  date: end of time          3
# 42     first name: Person  last name: Human  date: end of time          4
# 56     first name: Person  last name: Human  date: end of time          5
# ...                   ...               ...                ...        ...
# 76309  first name: Person  last name: Human  date: end of time       5990
# 76322  first name: Person  last name: Human  date: end of time       5991
# 76336  first name: Person  last name: Human  date: end of time       5992
# 76350  first name: Person  last name: Human  date: end of time       5993
# 76364  first name: Person  last name: Human  date: end of time       5994
#
# [5994 rows x 4 columns]

# %%
# Rename columns' name
renamed_cols = ["First Name", "Last Name", "Date", "Iteration"]
df_name.columns = renamed_cols
# Out:
#                First Name         Last Name               Date  Iteration
# 0      first name: Person  last name: Human  date: end of time          1
# 14     first name: Person  last name: Human  date: end of time          2
# 28     first name: Person  last name: Human  date: end of time          3
# 42     first name: Person  last name: Human  date: end of time          4
# 56     first name: Person  last name: Human  date: end of time          5
# ...                   ...               ...                ...        ...
# 76309  first name: Person  last name: Human  date: end of time       5990
# 76322  first name: Person  last name: Human  date: end of time       5991
# 76336  first name: Person  last name: Human  date: end of time       5992
# 76350  first name: Person  last name: Human  date: end of time       5993
# 76364  first name: Person  last name: Human  date: end of time       5994
#
# [5994 rows x 4 columns]

# %%
# Extract data we need
df_name[renamed_cols[:3]] = df_name[renamed_cols[:3]].applymap(lambda x: x.split(":")[1])
# Out:
# /Users/tim/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
df_name.head(10)
# Out:
#     First Name Last Name          Date  Iteration
# 0       Person     Human   end of time          1
# 14      Person     Human   end of time          2
# 28      Person     Human   end of time          3
# 42      Person     Human   end of time          4
# 56      Person     Human   end of time          5
# 68      Person     Human   end of time          6
# 80      Person     Human   end of time          7
# 92      Person     Human   end of time          8
# 104     Person     Human   end of time          9
# 116     Person     Human   end of time         10

# %% [markdown]
# ### Dataframe2 with other information

# %%
df_info = df.loc[~(df["Row Type"].str.contains("first name"))]
df_info
# Out:
#        Row Type  Iter Number  Power1  Speed1  Speed2  Electricity  Effort  \
# 2      Row Type  Iter Number  Power1  Speed1  Speed2  Electricity  Effort
# 3          Iter            1     360     108     863          599     680
# 4          Iter            2     684     508     613          241     249
# 5          Iter            3     365     126     825          407     855
# 6          Iter            4     764     594     304          718     278
# ...         ...          ...     ...     ...     ...          ...     ...
# 76372      Iter            6     879      73     977          680     500
# 76373   Average          979     641     531     374          448     407
# 76374   Maximum          783     172     941      53          982     217
# 76375  Std.Dev.          221     112     717     630          239     561
# 76376     Total          429       -       -       -            -     847
#
#        Weight  Torque  Iteration
# 2      Weight  Torque          1
# ...

# %%
# Drop the unnecessary info
df_info = df_info.loc[~(df_info["Row Type"].str.contains(r"Row Type|Total"))]
df_info.head()
# Out:
#   Row Type Iter Number Power1 Speed1 Speed2 Electricity Effort Weight Torque  \
# 3     Iter           1    360    108    863         599    680    442    982
# 4     Iter           2    684    508    613         241    249    758    639
# 5     Iter           3    365    126    825         407    855    164     86
# 6     Iter           4    764    594    304         718    278    674    774
# 7     Iter           5    487     97    593         206    779    800    123
#
#    Iteration
# 3          1
# 4          1
# 5          1
# 6          1
# 7          1

# %% [markdown]
# ## Join two data sets on Iteration

# %%
df_output = pd.merge(df_name, df_info, on='Iteration')
df_output
# Out:
#       First Name Last Name          Date  Iteration  Row Type Iter Number  \
# 0         Person     Human   end of time          1      Iter           1
# 1         Person     Human   end of time          1      Iter           2
# 2         Person     Human   end of time          1      Iter           3
# 3         Person     Human   end of time          1      Iter           4
# 4         Person     Human   end of time          1      Iter           5
# ...          ...       ...           ...        ...       ...         ...
# 40410     Person     Human   end of time       5994      Iter           5
# 40411     Person     Human   end of time       5994      Iter           6
# 40412     Person     Human   end of time       5994   Average         979
# 40413     Person     Human   end of time       5994   Maximum         783
# 40414     Person     Human   end of time       5994  Std.Dev.         221
#
#       Power1 Speed1 Speed2 Electricity Effort Weight Torque
# ...

# %%
df_output.to_csv("data_cleaning_output.csv", index=False)
